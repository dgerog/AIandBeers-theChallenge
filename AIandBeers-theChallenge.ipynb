# %% [markdown]
# ![AIandBeers-LOGO-small.png](data:image/png;base64,...)
#
# # Welcome AI Enthusiast!
#
# This is a basic Jupyter Notebook deployment to use for the various AIandBeers, theChallenge workshops. Use it to solve your challenges and submit your responses.
#
#
# Have fun!
#
# *theChallenge Team*
